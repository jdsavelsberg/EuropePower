# %%
import pandas as pd
import numpy as np
import os
import json
import requests

from pyjstat import pyjstat
from collections import OrderedDict
# Out:
# c:\Users\jonas\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
dir_out = "../parsed_data/"

# %%
map_country_ISO = {
    "Belgium" : "BE",
    "Bulgaria" : "BG",
    "Czechia" : "CZ",
    "Denmark" : "DK",
    "Germany" : "DE",  ## Leon 
    "Estonia" : "EE",
    "Ireland" : "IE",
    "Greece" : "EL",   ## Leon: Greece = EL 
    "Spain" : "ES",
    "France" : "FR",
    "Croatia" : "HR",
    "Italy" : "IT",
    "Cyprus" : "CY",
    "Latvia" : "LV",
    "Lithuania" : "LT",
    "Luxembourg" : "LU",
    "Hungary" : "HU",
    "Malta" : "MT",
    "Netherlands" : "NL",
    "Austria" : "AT",
    "Poland" : "PL",
    "Portugal" : "PT",
    "Romania" : "RO",
    "Slovenia" : "SI",
    "Slovakia" : "SK",
    "Finland" : "FI",
    "Sweden" : "SE",
    "United Kingdom" : "UK",  ## Leon: UK nicht GB
    "Iceland" : "IS",
    "Norway" : "NO",
    "Montenegro" : "ME",
    "North Macedonia" : "MK",
    "Albania" : "AL",
    "Serbia" : "RS",
    "Türkiye" : "TR",       ## Leon 
    "Bosnia and Herzegovina" : "BA",
    "Kosovo*" : "XK",     ## Leon 
    "Moldova" : "MD",
    "Ukraine" : "UA",
    "Georgia" : "GE",
    "Liechtenstein":"LI"  ## Leon, added 
}

print(list(map_country_ISO.values()))
# Out:
# ['BE', 'BG', 'CZ', 'DK', 'DE', 'EE', 'IE', 'EL', 'ES', 'FR', 'HR', 'IT', 'CY', 'LV', 'LT', 'LU', 'HU', 'MT', 'NL', 'AT', 'PL', 'PT', 'RO', 'SI', 'SK', 'FI', 'SE', 'UK', 'IS', 'NO', 'ME', 'MK', 'AL', 'RS', 'TR', 'BA', 'XK', 'MD', 'UA', 'GE', 'LI']

# %%
# Eurostat queries based on query builder: 
# https://ec.europa.eu/eurostat/web/query-builder/tool (Leon updated)
indicator = 'nrg_cb_e'
dataformat = 'JSON'

params = dict(
    siec = {'E7000'},
    sinceTimePeriod = '2014',
    geo = {'AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI', 'FR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MD', 'MK', 'MT', 'NL', 'NO', 'PL', 'PT', 'RO', 'RS', 'SE', 'SI', 'SK', 'TR', 'UA', 'UK', 'AL', 'BA', 'LI', 'IS', 'GE', 'ME', 'XK'},
    unit = 'GWH',
    nrg_bal = {'NEP','IMP','EXP','DL'}
)

print(", ".join(params["geo"]))
# Out:
# SI, FR, CY, AL, AT, RS, MD, FI, NO, UA, IS, RO, XK, PT, DK, CZ, EL, MK, IE, SK, BE, TR, HR, MT, GE, SE, BG, LT, EE, ME, HU, IT, PL, LU, UK, ES, LI, NL, BA, LV, DE

# %%
url = 'https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/'+indicator+'?format='+dataformat
r = requests.get(url=url, params=params)
nrg_cb_e = pd.DataFrame(pyjstat.from_json_stat(r.json(object_pairs_hook=OrderedDict))[0])

print(r.url)
#nrg_cb_e = pd.DataFrame(pyjstat.from_json_stat(r.json(object_pairs_hook=OrderedDict))[0])
# Out:
# https://ec.europa.eu/eurostat/api/dissemination/statistics/1.0/data/nrg_cb_e?format=JSON&siec=E7000&sinceTimePeriod=2014&geo=SI&geo=FR&geo=CY&geo=AL&geo=AT&geo=RS&geo=MD&geo=FI&geo=NO&geo=UA&geo=IS&geo=RO&geo=XK&geo=PT&geo=DK&geo=CZ&geo=EL&geo=MK&geo=IE&geo=SK&geo=BE&geo=TR&geo=HR&geo=MT&geo=GE&geo=SE&geo=BG&geo=LT&geo=EE&geo=ME&geo=HU&geo=IT&geo=PL&geo=LU&geo=UK&geo=ES&geo=LI&geo=NL&geo=BA&geo=LV&geo=DE&unit=GWH&nrg_bal=IMP&nrg_bal=NEP&nrg_bal=EXP&nrg_bal=DL

# %%
#rename countries and convert to MWh
nrg_cb_e = nrg_cb_e.dropna()
nrg_cb_e = nrg_cb_e.rename(columns={'Geopolitical entity (reporting)':'country'})
nrg_cb_e['country'] = nrg_cb_e['country'].map(map_country_ISO)
nrg_cb_e['load_MWh'] = nrg_cb_e['value'] * 1000
nrg_cb_e.head()
# Out:
#   Time frequency Energy balance  \
# 0         Annual        Imports
# 1         Annual        Imports
# 2         Annual        Imports
# 3         Annual        Imports
# 4         Annual        Imports
#
#   Standard international energy product classification (SIEC) Unit of measure  \
# 0                                        Electricity            Gigawatt-hour
# 1                                        Electricity            Gigawatt-hour
# 2                                        Electricity            Gigawatt-hour
# 3                                        Electricity            Gigawatt-hour
# 4                                        Electricity            Gigawatt-hour
#
#   country  Time    value    load_MWh
# 0      BE  2014  21791.0  21791000.0
# 1      BE  2015  23714.0  23714000.0
# 2      BE  2016  14648.0  14648000.0
# 3      BE  2017  14189.4  14189400.0
# 4      BE  2018  21635.9  21635900.0

# %%
nrg_cb_e["Energy balance"
         ].unique()
# Out:
# array(['Imports', 'Exports', 'Distribution losses',
#        'Net electricity production'], dtype=object)

# %%
nrg_cb_e_pivot = nrg_cb_e.pivot_table(index=['country','Time'],columns='Energy balance',values='load_MWh')
nrg_cb_e_pivot['load_MWh'] = nrg_cb_e_pivot['Net electricity production'] + nrg_cb_e_pivot['Imports'] - nrg_cb_e_pivot['Exports'] + nrg_cb_e_pivot['Distribution losses']
nrg_cb_e_pivot['DL_share'] = nrg_cb_e_pivot['Distribution losses']/nrg_cb_e_pivot['load_MWh']
nrg_cb_e_pivot.head()
# Out:
# Energy balance  Distribution losses    Exports    Imports  \
# country Time
# AL      2014                    NaN   183000.0  3250000.0
#         2015                    NaN   956000.0  2355000.0
#         2016                    NaN    42000.0        0.0
#         2017                    NaN        0.0  2914628.0
#         2018                    NaN  1763786.0   850480.0
#
# Energy balance  Net electricity production  load_MWh  DL_share
# country Time
# AL      2014                     4708000.0       NaN       NaN
#         2015                     5866000.0       NaN       NaN
#         2016                     7720000.0       NaN       NaN
#         2017                     4497807.0       NaN       NaN
#         2018                     8508253.0       NaN       NaN

# %%
df_load = pd.DataFrame(nrg_cb_e_pivot['load_MWh'])

# %%
df_load = pd.pivot_table(df_load, values='load_MWh', index=['country'], columns=['Time'])
df_load.head()
# Out:
# Time           2014        2015        2016        2017        2018  \
# country
# AL              NaN         NaN         NaN         NaN         NaN
# AT              NaN         NaN         NaN  74639510.0  74330516.0
# BA       14521000.0  14712000.0  14210000.0  14745000.0  14655000.0
# BE       87420900.0  88375400.0  88582100.0  89147100.0  89398300.0
# BG       33781000.0  34151000.0  34851000.0  35871136.0  34907104.0
#
# Time           2019        2020        2021        2022        2023  \
# country
# AL              NaN         NaN         NaN   8759579.0   8852260.0
# AT       74229713.0  71788986.0  75643154.0  78045607.0  74885762.0
# BA       13911000.0  12813000.0  13959000.0  13121000.0  12779000.0
# BE       88085000.0  85789600.0  88767900.0  87322700.0  85138000.0
# BG       34510765.0  33814694.0  34679496.0  35399233.0  35169747.0
#
# Time           2024
# country
# AL        9631454.0
# AT       76338645.0
# BA              NaN
# BE       86868927.0
# BG       36539091.0

# %%
df_load.to_csv(dir_out+'load_yearly_Eurostat.csv', encoding="utf-8")

# %%
nrg_cb_e_pivot['DL_share']
# Out:
# country  Time
# AL       2014         NaN
#          2015         NaN
#          2016         NaN
#          2017         NaN
#          2018         NaN
#                    ...
# XK       2020    0.139254
#          2021    0.129712
#          2022    0.000000
#          2023    0.060146
#          2024    0.000000
# Name: DL_share, Length: 438, dtype: float64
